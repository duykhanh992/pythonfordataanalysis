# %%
import pandas as pd 
import numpy as np

# %%
import matplotlib.pyplot as plt
import os
import scipy.stats as sts
# %matplotlib inline

# %%
pd.set_option("display.max_rows", 2000)
pd.set_option("display.max_columns", 999)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F236-CBC5
#
#  Directory of C:\Users\Khanh Pham\Documents\pythonfordataanalysis
#
# 10/01/2019  08:23 AM    <DIR>          .
# 10/01/2019  08:23 AM    <DIR>          ..
# 10/01/2019  08:21 AM    <DIR>          .ipynb_checkpoints
# 09/04/2019  01:23 PM             3,918 53.txt
# 09/22/2019  01:02 AM         1,815,718 Biglist 10.01.2018.xlsx
# 10/01/2019  08:21 AM                72 Biglist.ipynb
# 09/13/2019  12:23 PM             1,419 Class and Objects.ipynb
# 09/04/2019  01:02 PM           343,222 Data Exploration.html
# 09/04/2019  01:02 PM            66,124 Data Exploration.ipynb
# 09/26/2019  03:29 PM           178,452 Grad OT Contract green.docx
# 09/13/2019  12:31 PM               555 inhertiance.ipynb
# 09/04/2019  01:02 PM                23 README.md
# 09/04/2019  01:02 PM             4,423 sample_submission_predictdata.csv
# 09/04/2019  01:02 PM            21,955 test_predictdata.csv
# ...

# %%
df = pd.read_excel('Biglist 10.01.2018.xlsx',sheet_name="IN-PA")

# %%
df.head(10)
# Out:
#    Curr Term  Banner ID    Last Name First Name Middle Name Name Suffix  \
# 0     201860  A10005577         Seol    Jong-Ho         NaN         NaN
# 1     201860  A10010945  Yerramsetti    Praveen        Nagh         NaN
# 2     201860  A10042328          Loh       Weng      Kheong         NaN
# 3     201860  A10042670      Etlapur     Smitha         NaN         NaN
# 4     201860  A10042761   Jayaseelan       Hema         NaN         NaN
# 5     201860  A10482212       Abbasi   Muhammad      Salman         NaN
# 6     201860  A10487104         Song    Ja-Hyun         NaN         NaN
# 7     201860  A10496067         Tran        Duy         Duc         NaN
# 8     201860  A10629166       Mutala      David           M         NaN
# 9     201860  A11090327        Singh     Rashmi         NaN         NaN
#
#   Preferred First Name Enrolled/Admitted Status Gender Birth Date  \
# 0               Jongho                 Enrolled      M 1972-04-06
# ...

# %%
df1 =df.copy()

# %%
df1.columns = df1.columns.str.replace(' ','_')

# %%
df1.head(5)
# Out:
#    Curr_Term  Banner_ID    Last_Name First_Name Middle_Name Name_Suffix  \
# 0     201860  A10005577         Seol    Jong-Ho         NaN         NaN
# 1     201860  A10010945  Yerramsetti    Praveen        Nagh         NaN
# 2     201860  A10042328          Loh       Weng      Kheong         NaN
# 3     201860  A10042670      Etlapur     Smitha         NaN         NaN
# 4     201860  A10042761   Jayaseelan       Hema         NaN         NaN
#
#   Preferred_First_Name Enrolled/Admitted_Status Gender Birth_Date  ...  \
# 0               Jongho                 Enrolled      M 1972-04-06  ...
# 1              Praveen                 Enrolled      M 1976-12-20  ...
# 2                  Ben                 Enrolled      M 1982-04-27  ...
# 3               Smitha                 Enrolled      F 1983-03-18  ...
# 4                 Hema                 Enrolled      F 1979-03-18  ...
#
#   Application_Date Admit_Decision_Date Admit_Decision Admit_College  \
# ...

# %%
df1.describe(include=['object']) #get summary of categorical variables
# Out:
#         Banner_ID Last_Name First_Name Middle_Name Name_Suffix  \
# count        1765      1765       1765         649          62
# unique       1765      1209       1415         527           5
# top     A20140837        Li   Mohammed           A         Sr.
# freq            1        35         28          15          47
#
#        Preferred_First_Name Enrolled/Admitted_Status Gender Marital_Status  \
# count                  1562                     1765   1765           1107
# unique                 1261                        1      2              4
# top                     Ali                 Enrolled      M              S
# freq                     23                     1765   1138            861
#
#        Citizenship_Type  ... Perm_Zip      Perm_Country Admit_Decision  \
# count              1765  ...     1503              1123           1393
# unique                2  ...     1061                69              3
# ...

# %%
#Apply Function
#Create a new function:
def num_missing(x):
  return sum(x.isnull())
#Applying per column:
print("Missing values per column:")
print(df1.apply(num_missing, axis=0)) #axis=0 defines that function is to be applied on each column
# Out:
# Missing values per column:
# Curr_Term                            0
# Banner_ID                            0
# Last_Name                            0
# First_Name                           0
# Middle_Name                       1116
# Name_Suffix                       1703
# Preferred_First_Name               203
# Enrolled/Admitted_Status             0
# Gender                               0
# Birth_Date                           0
# Marital_Status                     658
# Citizenship_Type                     0
# Nation_of_Citizenship                1
# Nation_of_Birth                     63
# Visa_Type                            1
# SEVIS_Number                       304
# Reported_Race                        0
# Residency                            0
# Student_Status                       0
# Curr_Program                         0
# Curr_College                         0
# Curr_Degree                          0
# Curr_Major_1                         0
# ...
